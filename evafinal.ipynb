# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # importando pandas

# %%
wer = pd.read_csv('gas.csv')

# %%
datos = pd.read_csv('https://raw.githubusercontent.com/tellezHub/eva/ae69e734e5f6225442d4a89785941d14fd67e7b9/gas.csv')
wer=pd.DataFrame(datos)
wer.head()
# Out:
#    Year  Australia  Canada  France  ...  South Korea    UK   USA  Ecuador
# 0  2001        NaN    1.87    3.63  ...         2.05  2.82  1.16     1.25
# 1  2002       1.96    1.92    3.45  ...         2.49  3.01  1.14     1.30
# 2  2003       1.89    1.73    3.56  ...         2.65  3.06  1.13     1.36
# 3  2004       1.73    1.57    3.41  ...         2.88  2.84  1.11     1.55
# 4  2005       1.84    1.45    3.59  ...         2.87  2.99  1.11     1.33
#
# [5 rows x 12 columns]

# %%
print(wer)
# Out:
#     Year  Australia  Canada  France  ...  South Korea    UK   USA  Ecuador
# 0   2001        NaN    1.87    3.63  ...         2.05  2.82  1.16     1.25
# 1   2002       1.96    1.92    3.45  ...         2.49  3.01  1.14     1.30
# 2   2003       1.89    1.73    3.56  ...         2.65  3.06  1.13     1.36
# 3   2004       1.73    1.57    3.41  ...         2.88  2.84  1.11     1.55
# 4   2005       1.84    1.45    3.59  ...         2.87  2.99  1.11     1.33
# 5   2006       1.95    1.53    4.26  ...         2.94  3.21  1.15     1.48
# 6   2007       2.12    1.61    4.41  ...         3.18  3.34  1.23     1.65
# 7   2008       2.05    1.62    4.00  ...         3.34  3.83  1.23     1.64
# 8   2009       1.63    1.38    3.87  ...         3.04  4.06  1.06     1.49
# 9   2010       1.72    1.52    3.85  ...         3.80  4.29  1.17     1.96
# 10  2011       1.94    1.86    3.80  ...         4.18  4.58  1.51     1.66
# ...

# %%
wer
# Out:
#     Year  Australia  Canada  France  ...  South Korea    UK   USA  Ecuador
# 0   2001        NaN    1.87    3.63  ...         2.05  2.82  1.16     1.25
# 1   2002       1.96    1.92    3.45  ...         2.49  3.01  1.14     1.30
# 2   2003       1.89    1.73    3.56  ...         2.65  3.06  1.13     1.36
# 3   2004       1.73    1.57    3.41  ...         2.88  2.84  1.11     1.55
# 4   2005       1.84    1.45    3.59  ...         2.87  2.99  1.11     1.33
# 5   2006       1.95    1.53    4.26  ...         2.94  3.21  1.15     1.48
# 6   2007       2.12    1.61    4.41  ...         3.18  3.34  1.23     1.65
# 7   2008       2.05    1.62    4.00  ...         3.34  3.83  1.23     1.64
# 8   2009       1.63    1.38    3.87  ...         3.04  4.06  1.06     1.49
# 9   2010       1.72    1.52    3.85  ...         3.80  4.29  1.17     1.96
# 10  2011       1.94    1.86    3.80  ...         4.18  4.58  1.51     1.66
# ...

# %%
wer.head(5)
# Out:
#    Year  Australia  Canada  France  ...  South Korea    UK   USA  Ecuador
# 0  2001        NaN    1.87    3.63  ...         2.05  2.82  1.16     1.25
# 1  2002       1.96    1.92    3.45  ...         2.49  3.01  1.14     1.30
# 2  2003       1.89    1.73    3.56  ...         2.65  3.06  1.13     1.36
# 3  2004       1.73    1.57    3.41  ...         2.88  2.84  1.11     1.55
# 4  2005       1.84    1.45    3.59  ...         2.87  2.99  1.11     1.33
#
# [5 rows x 12 columns]

# %%
plt.plot(wer.Year, wer.Ecuador)
plt.show()

# %%
plt.plot(wer.Year, wer.Italy)
plt.show()

# %%
plt.figure(figsize=(8,5))

plt.title('Precios de la gasolina a lo largo del tiempo en USD', fontdict={'fontweight':'bold', 'fontsize': 18})

plt.plot(wer.Year, wer.Ecuador, 'b.-', label='Ecuador')
plt.plot(wer.Year, wer.Canada, 'r.-')
plt.plot(wer.Year, wer['South Korea'], 'g.-')
plt.plot(wer.Year, wer.Australia, 'y.-')

plt.xticks(wer.Year[::3].tolist()+[2011])

plt.xlabel('AÑOS')
plt.ylabel('US Dolares')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show()

# %%
wer.tail()
# Out:
#     Year  Australia  Canada  France  ...  South Korea    UK   USA  Ecuador
# 14  2015       2.72    2.37    4.99  ...         4.51  5.56  1.88     1.23
# 15  2016       3.23    2.89    5.46  ...         5.28  5.97  2.30     1.65
# 16  2017       3.54    3.26    5.88  ...         5.92  6.36  2.59     1.74
# 17  2018       3.85    3.59    6.60  ...         6.21  7.13  2.80     1.85
# 18  2019       4.45    4.08    7.51  ...         5.83  7.42  3.27     1.98
#
# [5 rows x 12 columns]

# %%
plt.figure(figsize=(15,8))
plt.ticklabel_format(style='plain')
wer.groupby('Year')['Germany'].sum().plot(kind='barh',legend='reverse',color={'y','b','r','g','k','c','m'})
plt.title('Variación de Precio de Gasolina En Germany')
plt.ylabel('')
plt.show()

# %%
plt.ticklabel_format(style='plain')

wer.Ecuador.groupby(wer.Year).sum().plot(kind='pie',cmap='Paired')
plt.axis("equal")
plt.ylabel("")
plt.title('Grafica de paste % por año en Ecuador',color='#4286f4')
plt.show()

# %%
Ecu = wer.loc[wer['Ecuador'] > 1.50].count()[0]
Usa = wer.loc[wer['USA'] > 1.50].count()[0]
Mex = wer.loc[wer['Mexico'] > 1.50].count()[0]

plt.figure(figsize=(8,5))

labels = ['Ecuador', 'USA', 'Mexico']
colors = ['#abcdef', '#aabbcc','#8E36E7' ]

plt.pie([Ecu, Usa, Mex], labels = labels, colors=colors, autopct='%.2f %%')

plt.title('Países con gasolina mayor a 1.5$ ')

plt.show()

# %%
labels = ['Ecuador', 'USA', 'France']
values = [1,4,2]

plt.figure(figsize=(5,3), dpi=100)

bars = plt.bar(labels, values)

patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.savefig('barchart.png', dpi=300)

plt.show()

# %%
#fifa = pd.read_csv('data.csv')
datos = pd.read_csv('https://raw.githubusercontent.com/tellezHub/eva/ae69e734e5f6225442d4a89785941d14fd67e7b9/data.csv')
fifa=pd.DataFrame(datos)
fifa.head(5)
# Out:
#    Unnamed: 0      ID  ... GKReflexes  Release Clause
# 0           0  158023  ...        8.0         €226.5M
# 1           1   20801  ...       11.0         €127.1M
# 2           2  190871  ...       11.0         €228.1M
# 3           3  193080  ...       94.0         €138.6M
# 4           4  192985  ...       13.0         €196.4M
#
# [5 rows x 89 columns]

# %%
bins = [40,50,60,70,80,90,100]

plt.figure(figsize=(8,5))

plt.hist(fifa.Overall, bins=bins, color='#abcdef')

plt.xticks(bins)

plt.ylabel('Numero de jugadores')
plt.xlabel('Skill Level')
plt.title('Distribución de las habilidades del jugador en FIFA 2018')

plt.savefig('histogram.png', dpi=300)

plt.show()

# %%
fifa.tail()
# Out:
#        Unnamed: 0      ID  ... GKReflexes  Release Clause
# 18202       18202  238813  ...        9.0           €143K
# 18203       18203  243165  ...       12.0           €113K
# 18204       18204  241638  ...       13.0           €165K
# 18205       18205  246268  ...        9.0           €143K
# 18206       18206  246269  ...        9.0           €165K
#
# [5 rows x 89 columns]

# %%
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

plt.figure(figsize=(8,5))

labels = ['Izquierda', 'Derecha']
colors = ['#abcdef', '#aabbcc']

plt.pie([left, right], labels = labels, colors=colors, autopct='%.2f %%')

plt.title('Preferencia de pie de las jugador FIFA ')

plt.show()

# %%
plt.figure(figsize=(8,5), dpi=100)

plt.style.use('ggplot')

fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[fifa.Weight >= 200].count()[0]

weights = [light,light_medium, medium, medium_heavy, heavy]
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']
explode = (.4,.2,0,0,.4)

plt.title('Peso de los futbolistas (lbs)')

plt.pie(weights, labels=label, explode=explode, pctdistance=0.8,autopct='%.2f %%')
plt.show()

# %%
plt.figure(figsize=(5,8), dpi=100)

plt.style.use('default')

barcelona = fifa.loc[fifa.Club == "FC Barcelona"]['Overall']
madrid = fifa.loc[fifa.Club == "Real Madrid"]['Overall']
revs = fifa.loc[fifa.Club == "New England Revolution"]['Overall']


bp = plt.boxplot([barcelona, madrid, revs], labels=['FC Barcelona','Real Madrid','NE Revolution'], patch_artist=True, medianprops={'linewidth': 2})
plt.title('Comparación de equipos de fútbol profesional')
plt.ylabel('Calificación General FIFA')

for box in bp['boxes']:
    
    box.set(color='#4286f4', linewidth=2)
   
    box.set(facecolor = '#e0e0e0' )
    
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
